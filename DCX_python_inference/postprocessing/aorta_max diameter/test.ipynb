# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from aortav2_test_plus_20250324 import compute_diameter

# %%
folder = "./input/1"

file_dict = {}
for i, file in enumerate(sorted(os.listdir(folder))):
    if file.endswith("2048.nii"):
        head = file.split(".dcm")[0]
        if head in file_dict:
            file_dict[head].append(file)
            file_dict[head] = sorted(file_dict[head])
            # break
        else:
            file_dict[head] = [file]
            
output_path = "E:/test_output_0423"

if os.path.exists(output_path):
    done_files = os.listdir(output_path)
else:
    done_files = []
    os.makedirs(output_path)


for head in file_dict:

    #if "{}.png".format(head) in done_files:
    #    print("done")
    #else:
        try:
            compute_diameter(output_path, folder, file_dict, head, visualize=True, heat_map=False)
        except ValueError:
            print(head, "ValueError")
            continue
        except FileNotFoundError:
            print(head, "FileNotFoundError")
            continue
# Out:
# 2.dcm_aorta.png_0_2048.nii
# (0.186025, 0.18555)
# pix_size :  (0.186025, 0.18555)
# v_range / h_range
# 1.8186046511627907
# return non
# v_range / h_range
# 3.6511627906976742
# a_coeff :  2.3043060523789784e-07
# b_coeff :  -0.0010850973287185243
# c_coeff :  366037.8650452554
# d_coeff :  -327849679.651045
# orthogonal_xs sum :  (640197737.108919-3.725290298461914e-08j)
# orthogonal_ys sum :  (36650902.64700829+8.96397978067398e-09j)
# closest_idx sum :  0
# closest_x sum :  209001034.06406352
# closest_y sum :  146455344.6518585
# <<<<<< iteration :  0
# g_c sum :  -2310.715922003179
# J_c sum :  -316175333492.2328
# new_beta :  [ 4.03566301e-04 -1.26371293e+00  2.04761639e+03]
# a_coeff :  3.2573151879088143e-07
# b_coeff :  -0.0015299758537672692
# c_coeff :  459547.2397733916
# d_coeff :  -375725145.33728707
# C:\Users\mip_aic\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:211: LinAlgWarning: Ill-conditioned matrix (rcond=6.34264e-17): result may not be accurate.
# ...
